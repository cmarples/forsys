# %%
import sys
sys.path.append('..')
sys.path.insert(0, '../../forsys')
import os
import forsys as fs

# %%
CHASTE_OUTPUT_NAME = "..\..\forsys_reading_chaste\data\Sep_25\R_Furrow_SmallAreaTerm_Sampling"
CHASTE_OUTPUT_FOLDER = os.path.join("data", CHASTE_OUTPUT_NAME)

FRAME_FILE = os.path.join("results_from_time_0", "results_2000.vtu")
FRAME_FILE_PATH = os.path.join(CHASTE_OUTPUT_FOLDER, FRAME_FILE)

# Load Chaste frame into a lattice
lattice = fs.chaste.Chaste(CHASTE_OUTPUT_FOLDER, FRAME_FILE_PATH)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 8
#       5 FRAME_FILE_PATH = os.path.join(CHASTE_OUTPUT_FOLDER, FRAME_FILE)
#       7 # Load Chaste frame into a lattice
# ----> 8 lattice = fs.chaste.Chaste(CHASTE_OUTPUT_FOLDER, FRAME_FILE_PATH)
#
# File <string>:5, in __init__(self, dirname, fname)
#
# File ~\Research Code\forsys\examples\../../forsys\forsys\chaste.py:24, in Chaste.__post_init__(self)
#      23 def __post_init__(self):
# ---> 24     self.vertices, self.edges, self.cells = self.create_lattice()
#
# File ~\Research Code\forsys\examples\../../forsys\forsys\chaste.py:38, in Chaste.create_lattice(self)
#      36 edges  = {}
#      37 cells = {}
# ---> 38 vertex_list, edge_list, face_list = self.read_vtu_file()
#      39 ground_truth_tensions = self.read_line_tensions()
#      41 # build vertex dictionary
#
# File ~\Research Code\forsys\examples\../../forsys\forsys\chaste.py:66, in Chaste.read_vtu_file(self)
#      64 def read_vtu_file(self):
#      65     # Read file
# ---> 66     mesh = pv.read(self.fname)
#      67     vertex_list = mesh.points.tolist()
#      68     face_array = mesh.cells # this is a 1D array
#
# File ~\anaconda3\envs\forsys\Lib\site-packages\pyvista\_deprecate_positional_args.py:245, in _deprecate_positional_args.<locals>._inner_deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#     241             warnings.warn(msg, PyVistaDeprecationWarning, stacklevel=stack_level)
#     243         warn_positional_args()
# --> 245 return f(*args, **kwargs)
#
# File ~\anaconda3\envs\forsys\Lib\site-packages\pyvista\core\utilities\fileio.py:267, in read(filename, force_ext, file_format, progress_bar)
#     265 if not filename.is_file() and not filename.is_dir():
#     266     msg = f'File ({filename}) not found'
# --> 267     raise FileNotFoundError(msg)
#     269 # Read file using meshio.read if file_format is present
#     270 if file_format:
#
# FileNotFoundError: File (C:\Users\cmarp\Research Code\forsys\examples\..orsys_reading_chaste\data\Sep_25\R_Furrow_SmallAreaTerm_Sampling\results_from_time_0\results_2000.vtu) not found

# %%
# Assign frames and create main ForSys object
frames = {}
frames[0] = fs.frames.Frame(0,
                            lattice.vertices,
                            lattice.edges, 
                            lattice.cells,
                            gt=True)
forsys = fs.ForSys(frames)

# %%
# Build and solve the system of equations for the force
forsys.build_force_matrix(when=0)
forsys.solve_stress(when=0, allow_negatives=False)

# %%
# Build and solve the system of equations for the pressure
forsys.build_pressure_matrix(when=0)
forsys.solve_pressure(when=0, method="lagrange_pressure")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Build and solve the system of equations for the pressure
# ----> 2 forsys.build_pressure_matrix(when=0)
#       3 forsys.solve_pressure(when=0, method="lagrange_pressure")
#
# NameError: name 'forsys' is not defined

# %%
# Plot with ground truth
fig2, ax2 = fs.plot.plot_inference(forsys.frames[0],
                                   ground_truth=True,
                                   normalized="max",
                                   mirror_y=False,
                                   colorbar=True,
                                   pressure=False)

# %%
# Plot with inferred
fig, ax = fs.plot.plot_inference(forsys.frames[0],
                                 normalized="max",
                                 mirror_y=False,
                                 colorbar=True,
                                 pressure=False)
